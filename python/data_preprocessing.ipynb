# %% [markdown]
# ## Project: Poverty

# %%
import pandas as pd

# %% [markdown]
# ### Poverty data fetched from World Bank
# The data includes 108 columns including general information like country, year, reporting level, survey comparability, etc., and other digital data.
#
# Data Source: World Bank`s Poverty and Inequality Platform (PIP), extracted by owid. https://github.com/owid/poverty-data

# %%
df = pd.read_csv("poverty_dataset.csv")
df.head()
# Out:
#    country  year reporting_level welfare_type  ppp_version  survey_year  \
# 0  Albania  1996        national  consumption         2011       1996.0
# 1  Albania  2002        national  consumption         2011       2002.0
# 2  Albania  2005        national  consumption         2011       2005.0
# 3  Albania  2008        national  consumption         2011       2008.0
# 4  Albania  2012        national  consumption         2011       2012.0
#
#    survey_comparability  headcount_ratio_international_povline  \
# 0                   0.0                               0.920669
# 1                   1.0                               1.570843
# 2                   1.0                               0.860527
# 3                   1.0                               0.313650
# 4                   1.0                               0.849754
#
#    headcount_ratio_lower_mid_income_povline  \
# 0                                 11.174149
# 1                                 14.132118
# 2                                  8.715685
# 3                                  5.250542
# 4                                  6.182414
#
#    headcount_ratio_upper_mid_income_povline  ...  decile8_thr  decile9_thr  \
# 0                                 44.618417  ...         8.85        10.92
# 1                                 49.669635  ...         8.83        11.58
# 2                                 38.545254  ...        10.02        12.78
# 3                                 31.110345  ...        10.74        13.62
# 4                                 34.528906  ...        10.52        13.26
#
#        gini       mld  polarization  palma_ratio  s80_s20_ratio  \
# 0  0.270103  0.119104      0.241293     0.928335       3.945872
# 1  0.317390  0.164812      0.268982     1.215056       4.831625
# 2  0.305957  0.154413      0.254529     1.142718       4.662236
# 3  0.299847  0.148893      0.247311     1.114657       4.395911
# 4  0.289605  0.138417      0.249988     1.041193       4.272573
#
#    p90_p10_ratio  p90_p50_ratio  p50_p10_ratio
# 0       3.568627       1.889273       1.888889
# 1       3.979381       2.090253       1.903780
# 2       3.872727       1.978328       1.957576
# 3       3.574803       1.956897       1.826772
# 4       3.632877       1.941435       1.871233
#
# [5 rows x 108 columns]

# %% [markdown]
# #### headcount data
# Columns 8 to 29 are the headcount data. They basiclly tell the percentage or the number of people living under certain line (for instance, certain expenditure per day per person or certain percentage of the population).
#
# Below is an example of column 8: % of population living in households with an income or expenditure per person below the International Poverty Line: 1.90 dollar a day (in 2011 prices) or 2.15 dollar a day (in 2017 prices).

# %%
df["headcount_ratio_international_povline"].describe()
# Out:
# count    4877.000000
# mean       11.081565
# std        18.190433
# min         0.000000
# 25%         0.278387
# 50%         2.041412
# 75%        13.390963
# max        96.871427
# Name: headcount_ratio_international_povline, dtype: float64

# %% [markdown]
# #### shortfall and gap data
# Columns 30 to 62 are the shortfall data.They describe the shortfall to the line that ensures the basic needs for living.
#
# Columns 63 to 70 are the gap data. It is defined as the mean shortfall of the total population from the poverty line counting the non-poor as having zero shortfall and expressed as a percentage of the poverty line.
#
# Below shows the total shortfall from the upper-middle income poverty line: 5.50 dollar a day (in 2011 prices) or 6.85 dollar a day (in 2017 prices). This is the amount of money that would be theoretically needed to lift the incomes or expenditure of all people in poverty up to the poverty line.
#
# However this is not a measure of the actual cost of eliminating poverty, since it does not take into account the costs involved in making the necessary transfers nor any changes in behaviour they would bring about.

# %%
df["avg_shortfall_upper_mid_income_povline"].sort_values()
# Out:
# 2155    0.059127
# 820     0.219790
# 255     0.227310
# 2156    0.240166
# 734     0.280244
#           ...
# 2525         NaN
# 3809         NaN
# 3810         NaN
# 3812         NaN
# 4712         NaN
# Name: avg_shortfall_upper_mid_income_povline, Length: 4877, dtype: float64

# %% [markdown]
# As you can see, there are many blank cells in the dataset. It would be dealt later in the data processing part.

# %% [markdown]
# #### mean and threshold data for different deciles of people
# Columns 71 to 100 are the mean and threshold data. They describe the average income or the income threshold for certain decile (tenth of the population).
#
# For instance, column "decile10_share" tells the income or expenditure of the richest decile (tenth of the population) as a share of total income or expenditure.

# %%
df["decile10_share"].describe()
# Out:
# count    4395.000000
# mean       29.434217
# std         6.742275
# min        16.985789
# 25%        24.479009
# 50%        27.494046
# 75%        32.899965
# max        61.491135
# Name: decile10_share, dtype: float64

# %% [markdown]
# #### other data or index related
# Columns 101 to 108 are the data and indexs related to poverty. Such as Gini index or MLD.

# %%
df["gini"].describe()
# Out:
# count    4401.000000
# mean        0.375645
# std         0.088840
# min         0.177920
# 25%         0.308719
# 50%         0.355622
# 75%         0.427676
# max         0.657556
# Name: gini, dtype: float64

# %% [markdown]
# ### Tree data
# The first visualization would be a tree of countries divided by geographical location. So this section would focus on the transformation from raw data to a tree.

# %%
new_df = pd.DataFrame({"country": df["country"], "year": df["year"], "median": df["median"]})
for i in range(len(new_df["country"])):
    if new_df["country"][i] == "Zimbabwe":
        break
    if new_df["country"][i + 1] != new_df["country"][i]:
        continue
    if new_df["country"][i + 1] == new_df["country"][i]:
        new_df = new_df.drop(labels=i)
print(new_df)
new_df.to_excel("tree.xlsx")
# Out:
#         country  year     median
# 13      Albania  2019  10.831646
# 16      Algeria  2011   7.158526
# 19       Angola  2018   1.901955
# 51    Argentina  2020  12.176018
# 73      Armenia  2020   5.800005
# ...         ...   ...        ...
# 4872     Zambia  2010   1.353084
# 4873     Zambia  2015   1.570981
# 4874   Zimbabwe  2011   3.798868
# 4875   Zimbabwe  2017   2.874558
# 4876   Zimbabwe  2019   2.654817
#
# [2617 rows x 3 columns]

# %% [markdown]
# For the generation of tree data, we need extra data of countries divided by regions.
#
# Source: United Nations, extracted by Curran Kelleher. https://github.com/curran/data/tree/gh-pages/un/placeHierarchy

# %%
from anytree.importer import JsonImporter
from anytree.exporter import JsonExporter
from anytree import RenderTree, LevelOrderIter, Node
import json

importer = JsonImporter()
exporter = JsonExporter(indent=2, sort_keys=True)
country_js = open("countries.json")
country_data = json.load(country_js)
root = importer.import_(json.dumps(country_data))  # convert json to str
print(RenderTree(root))
# Out:
# AnyNode(data={'id': 'World'})
# ├── AnyNode(data={'id': 'Asia'})
# │   ├── AnyNode(data={'id': 'Southern Asia'})
# │   │   ├── AnyNode(data={'id': 'Afghanistan'})
# │   │   ├── AnyNode(data={'id': 'Bangladesh'})
# │   │   ├── AnyNode(data={'id': 'Bhutan'})
# │   │   ├── AnyNode(data={'id': 'India'})
# │   │   ├── AnyNode(data={'id': 'Iran'})
# │   │   ├── AnyNode(data={'id': 'Maldives'})
# │   │   ├── AnyNode(data={'id': 'Nepal'})
# │   │   ├── AnyNode(data={'id': 'Pakistan'})
# │   │   └── AnyNode(data={'id': 'Sri Lanka'})
# │   ├── AnyNode(data={'id': 'Western Asia'})
# │   │   ├── AnyNode(data={'id': 'Armenia'})
# │   │   ├── AnyNode(data={'id': 'Azerbaijan'})
# │   │   ├── AnyNode(data={'id': 'Bahrain'})
# │   │   ├── AnyNode(data={'id': 'Cyprus'})
# │   │   ├── AnyNode(data={'id': 'Georgia'})
# │   │   ├── AnyNode(data={'id': 'Iraq'})
# │   │   ├── AnyNode(data={'id': 'Israel'})
# │   │   ├── AnyNode(data={'id': 'Jordan'})
# │   │   ├── AnyNode(data={'id': 'Kuwait'})
# │   │   ├── AnyNode(data={'id': 'Lebanon'})
# │   │   ├── AnyNode(data={'id': 'Oman'})
# │   │   ├── AnyNode(data={'id': 'Qatar'})
# │   │   ├── AnyNode(data={'id': 'Saudi Arabia'})
# │   │   ├── AnyNode(data={'id': 'Palestine'})
# │   │   ├── AnyNode(data={'id': 'Syrian'})
# │   │   ├── AnyNode(data={'id': 'Turkey'})
# │   │   ├── AnyNode(data={'id': 'United Arab Emirates'})
# │   │   └── AnyNode(data={'id': 'Yemen'})
# │   ├── AnyNode(data={'id': 'South-Eastern Asia'})
# │   │   ├── AnyNode(data={'id': 'Brunei Darussalam'})
# │   │   ├── AnyNode(data={'id': 'Cambodia'})
# │   │   ├── AnyNode(data={'id': 'Indonesia'})
# │   │   ├── AnyNode(data={'id': 'Laos'})
# │   │   ├── AnyNode(data={'id': 'Malaysia'})
# │   │   ├── AnyNode(data={'id': 'Myanmar'})
# │   │   ├── AnyNode(data={'id': 'Philippines'})
# │   │   ├── AnyNode(data={'id': 'Singapore'})
# │   │   ├── AnyNode(data={'id': 'Thailand'})
# │   │   ├── AnyNode(data={'id': 'Timor'})
# │   │   └── AnyNode(data={'id': 'Vietnam'})
# │   ├── AnyNode(data={'id': 'Eastern Asia'})
# │   │   ├── AnyNode(data={'id': 'China'})
# │   │   ├── AnyNode(data={'id': 'Japan'})
# │   │   ├── AnyNode(data={'id': 'Mongolia'})
# │   │   └── AnyNode(data={'id': 'South Korea'})
# │   └── AnyNode(data={'id': 'Central Asia'})
# │       ├── AnyNode(data={'id': 'Kazakhstan'})
# │       ├── AnyNode(data={'id': 'Kyrgyzstan'})
# │       ├── AnyNode(data={'id': 'Tajikistan'})
# │       ├── AnyNode(data={'id': 'Turkmenistan'})
# │       └── AnyNode(data={'id': 'Uzbekistan'})
# ├── AnyNode(data={'id': 'Europe'})
# │   ├── AnyNode(data={'id': 'Southern Europe'})
# │   │   ├── AnyNode(data={'id': 'Albania'})
# │   │   ├── AnyNode(data={'id': 'Andorra'})
# │   │   ├── AnyNode(data={'id': 'Bosnia and Herzegovina'})
# │   │   ├── AnyNode(data={'id': 'Croatia'})
# │   │   ├── AnyNode(data={'id': 'Gibraltar'})
# │   │   ├── AnyNode(data={'id': 'Greece'})
# │   │   ├── AnyNode(data={'id': 'Italy'})
# │   │   ├── AnyNode(data={'id': 'Malta'})
# │   │   ├── AnyNode(data={'id': 'Montenegro'})
# │   │   ├── AnyNode(data={'id': 'Portugal'})
# │   │   ├── AnyNode(data={'id': 'San Marino'})
# │   │   ├── AnyNode(data={'id': 'Serbia'})
# │   │   ├── AnyNode(data={'id': 'Slovenia'})
# │   │   ├── AnyNode(data={'id': 'Spain'})
# │   │   └── AnyNode(data={'id': 'Macedonia'})
# │   ├── AnyNode(data={'id': 'Western Europe'})
# │   │   ├── AnyNode(data={'id': 'Austria'})
# │   │   ├── AnyNode(data={'id': 'Belgium'})
# │   │   ├── AnyNode(data={'id': 'France'})
# │   │   ├── AnyNode(data={'id': 'Germany'})
# │   │   ├── AnyNode(data={'id': 'Liechtenstein'})
# │   │   ├── AnyNode(data={'id': 'Luxembourg'})
# │   │   ├── AnyNode(data={'id': 'Monaco'})
# │   │   ├── AnyNode(data={'id': 'Netherlands'})
# │   │   └── AnyNode(data={'id': 'Switzerland'})
# │   ├── AnyNode(data={'id': 'Eastern Europe'})
# │   │   ├── AnyNode(data={'id': 'Belarus'})
# │   │   ├── AnyNode(data={'id': 'Bulgaria'})
# │   │   ├── AnyNode(data={'id': 'Czechia'})
# │   │   ├── AnyNode(data={'id': 'Hungary'})
# │   │   ├── AnyNode(data={'id': 'Poland'})
# │   │   ├── AnyNode(data={'id': 'Moldova'})
# │   │   ├── AnyNode(data={'id': 'Romania'})
# │   │   ├── AnyNode(data={'id': 'Russia'})
# │   │   ├── AnyNode(data={'id': 'Slovakia'})
# │   │   └── AnyNode(data={'id': 'Ukraine'})
# │   └── AnyNode(data={'id': 'Northern Europe'})
# │       ├── AnyNode(data={'id': 'Denmark'})
# │       ├── AnyNode(data={'id': 'Estonia'})
# │       ├── AnyNode(data={'id': 'Finland'})
# │       ├── AnyNode(data={'id': 'Iceland'})
# │       ├── AnyNode(data={'id': 'Ireland'})
# │       ├── AnyNode(data={'id': 'Latvia'})
# │       ├── AnyNode(data={'id': 'Lithuania'})
# │       ├── AnyNode(data={'id': 'Norway'})
# │       ├── AnyNode(data={'id': 'Sweden'})
# │       └── AnyNode(data={'id': 'United Kingdom'})
# ├── AnyNode(data={'id': 'Africa'})
# │   ├── AnyNode(data={'id': 'Northern Africa'})
# │   │   ├── AnyNode(data={'id': 'Algeria'})
# │   │   ├── AnyNode(data={'id': 'Egypt'})
# │   │   ├── AnyNode(data={'id': 'Libya'})
# │   │   ├── AnyNode(data={'id': 'Morocco'})
# │   │   ├── AnyNode(data={'id': 'Sudan'})
# │   │   └── AnyNode(data={'id': 'Tunisia'})
# │   ├── AnyNode(data={'id': 'Middle Africa'})
# │   │   ├── AnyNode(data={'id': 'Angola'})
# │   │   ├── AnyNode(data={'id': 'Cameroon'})
# │   │   ├── AnyNode(data={'id': 'Central African Republic'})
# │   │   ├── AnyNode(data={'id': 'Chad'})
# │   │   ├── AnyNode(data={'id': 'Congo'})
# │   │   ├── AnyNode(data={'id': 'Democratic Republic of the Congo'})
# │   │   ├── AnyNode(data={'id': 'Equatorial Guinea'})
# │   │   ├── AnyNode(data={'id': 'Gabon'})
# │   │   └── AnyNode(data={'id': 'Sao Tome and Principe'})
# │   ├── AnyNode(data={'id': 'Western Africa'})
# │   │   ├── AnyNode(data={'id': 'Benin'})
# │   │   ├── AnyNode(data={'id': 'Burkina Faso'})
# │   │   ├── AnyNode(data={'id': 'Cape Verde'})
# │   │   ├── AnyNode(data={'id': "Cote d'Ivoire"})
# │   │   ├── AnyNode(data={'id': 'Gambia'})
# │   │   ├── AnyNode(data={'id': 'Ghana'})
# │   │   ├── AnyNode(data={'id': 'Guinea'})
# │   │   ├── AnyNode(data={'id': 'Guinea-Bissau'})
# │   │   ├── AnyNode(data={'id': 'Liberia'})
# │   │   ├── AnyNode(data={'id': 'Mali'})
# │   │   ├── AnyNode(data={'id': 'Mauritania'})
# │   │   ├── AnyNode(data={'id': 'Niger'})
# │   │   ├── AnyNode(data={'id': 'Nigeria'})
# │   │   ├── AnyNode(data={'id': 'Saint Helena'})
# │   │   ├── AnyNode(data={'id': 'Senegal'})
# │   │   ├── AnyNode(data={'id': 'Sierra Leone'})
# │   │   └── AnyNode(data={'id': 'Togo'})
# │   ├── AnyNode(data={'id': 'Southern Africa'})
# │   │   ├── AnyNode(data={'id': 'Botswana'})
# │   │   ├── AnyNode(data={'id': 'Lesotho'})
# │   │   ├── AnyNode(data={'id': 'Namibia'})
# │   │   ├── AnyNode(data={'id': 'South Africa'})
# │   │   └── AnyNode(data={'id': 'Swaziland'})
# │   └── AnyNode(data={'id': 'Eastern Africa'})
# │       ├── AnyNode(data={'id': 'Burundi'})
# │       ├── AnyNode(data={'id': 'Comoros'})
# │       ├── AnyNode(data={'id': 'Djibouti'})
# │       ├── AnyNode(data={'id': 'Eritrea'})
# │       ├── AnyNode(data={'id': 'Ethiopia'})
# │       ├── AnyNode(data={'id': 'Kenya'})
# │       ├── AnyNode(data={'id': 'Madagascar'})
# │       ├── AnyNode(data={'id': 'Malawi'})
# │       ├── AnyNode(data={'id': 'Mauritius'})
# │       ├── AnyNode(data={'id': 'Mayotte'})
# │       ├── AnyNode(data={'id': 'Mozambique'})
# │       ├── AnyNode(data={'id': 'R茅union'})
# │       ├── AnyNode(data={'id': 'Rwanda'})
# │       ├── AnyNode(data={'id': 'Seychelles'})
# │       ├── AnyNode(data={'id': 'Somalia'})
# │       ├── AnyNode(data={'id': 'South Sudan'})
# │       ├── AnyNode(data={'id': 'Uganda'})
# │       ├── AnyNode(data={'id': 'Tanzania'})
# │       ├── AnyNode(data={'id': 'Zambia'})
# │       └── AnyNode(data={'id': 'Zimbabwe'})
# ├── AnyNode(data={'id': 'Oceania'})
# │   ├── AnyNode(data={'id': 'Polynesia'})
# │   │   ├── AnyNode(data={'id': 'Samoa'})
# │   │   ├── AnyNode(data={'id': 'Cook Islands'})
# │   │   ├── AnyNode(data={'id': 'French Polynesia'})
# │   │   ├── AnyNode(data={'id': 'Niue'})
# │   │   ├── AnyNode(data={'id': 'Samoa'})
# │   │   ├── AnyNode(data={'id': 'Tokelau'})
# │   │   ├── AnyNode(data={'id': 'Tonga'})
# │   │   ├── AnyNode(data={'id': 'Tuvalu'})
# │   │   └── AnyNode(data={'id': 'Wallis and Futuna Islands'})
# │   ├── AnyNode(data={'id': 'Australia and New Zealand'})
# │   │   ├── AnyNode(data={'id': 'Australia'})
# │   │   └── AnyNode(data={'id': 'New Zealand'})
# │   ├── AnyNode(data={'id': 'Melanesia'})
# │   │   ├── AnyNode(data={'id': 'Fiji'})
# │   │   ├── AnyNode(data={'id': 'New Caledonia'})
# │   │   ├── AnyNode(data={'id': 'Papua New Guinea'})
# │   │   ├── AnyNode(data={'id': 'Solomon Islands'})
# │   │   └── AnyNode(data={'id': 'Vanuatu'})
# │   └── AnyNode(data={'id': 'Micronesia'})
# │       ├── AnyNode(data={'id': 'Guam'})
# │       ├── AnyNode(data={'id': 'Kiribati'})
# │       ├── AnyNode(data={'id': 'Marshall Islands'})
# │       ├── AnyNode(data={'id': 'Micronesia'})
# │       ├── AnyNode(data={'id': 'Nauru'})
# │       ├── AnyNode(data={'id': 'Northern Mariana Islands'})
# │       └── AnyNode(data={'id': 'Palau'})
# ├── AnyNode(data={'id': 'Latin America'})
# │   ├── AnyNode(data={'id': 'Caribbean'})
# │   │   ├── AnyNode(data={'id': 'Anguilla'})
# │   │   ├── AnyNode(data={'id': 'Antigua and Barbuda'})
# │   │   ├── AnyNode(data={'id': 'Aruba'})
# │   │   ├── AnyNode(data={'id': 'Bahamas'})
# │   │   ├── AnyNode(data={'id': 'Barbados'})
# │   │   ├── AnyNode(data={'id': 'British Virgin Islands'})
# │   │   ├── AnyNode(data={'id': 'Bonaire, Sint Eustatius and Saba'})
# │   │   ├── AnyNode(data={'id': 'Cayman Islands'})
# │   │   ├── AnyNode(data={'id': 'Cuba'})
# │   │   ├── AnyNode(data={'id': 'Cura莽ao'})
# │   │   ├── AnyNode(data={'id': 'Dominica'})
# │   │   ├── AnyNode(data={'id': 'Dominican Republic'})
# │   │   ├── AnyNode(data={'id': 'Grenada'})
# │   │   ├── AnyNode(data={'id': 'Guadeloupe'})
# │   │   ├── AnyNode(data={'id': 'Haiti'})
# │   │   ├── AnyNode(data={'id': 'Jamaica'})
# │   │   ├── AnyNode(data={'id': 'Martinique'})
# │   │   ├── AnyNode(data={'id': 'Montserrat'})
# │   │   ├── AnyNode(data={'id': 'Puerto Rico'})
# │   │   ├── AnyNode(data={'id': 'Saint Kitts and Nevis'})
# │   │   ├── AnyNode(data={'id': 'Saint Lucia'})
# │   │   ├── AnyNode(data={'id': 'Saint Vincent and the Grenadines'})
# │   │   ├── AnyNode(data={'id': 'Sint Maarten (Dutch part)'})
# │   │   ├── AnyNode(data={'id': 'Trinidad and Tobago'})
# │   │   ├── AnyNode(data={'id': 'Turks and Caicos Islands'})
# │   │   └── AnyNode(data={'id': 'United States Virgin Islands'})
# │   ├── AnyNode(data={'id': 'South America'})
# │   │   ├── AnyNode(data={'id': 'Argentina'})
# │   │   ├── AnyNode(data={'id': 'Bolivia'})
# │   │   ├── AnyNode(data={'id': 'Brazil'})
# │   │   ├── AnyNode(data={'id': 'Chile'})
# │   │   ├── AnyNode(data={'id': 'Colombia'})
# │   │   ├── AnyNode(data={'id': 'Ecuador'})
# │   │   ├── AnyNode(data={'id': 'Falkland Islands (Malvinas)'})
# │   │   ├── AnyNode(data={'id': 'French Guiana'})
# │   │   ├── AnyNode(data={'id': 'Guyana'})
# │   │   ├── AnyNode(data={'id': 'Paraguay'})
# │   │   ├── AnyNode(data={'id': 'Peru'})
# │   │   ├── AnyNode(data={'id': 'Suriname'})
# │   │   ├── AnyNode(data={'id': 'Uruguay'})
# │   │   └── AnyNode(data={'id': 'Venezuela'})
# │   └── AnyNode(data={'id': 'Central America'})
# │       ├── AnyNode(data={'id': 'Belize'})
# │       ├── AnyNode(data={'id': 'Costa Rica'})
# │       ├── AnyNode(data={'id': 'El Salvador'})
# │       ├── AnyNode(data={'id': 'Guatemala'})
# │       ├── AnyNode(data={'id': 'Honduras'})
# │       ├── AnyNode(data={'id': 'Mexico'})
# │       ├── AnyNode(data={'id': 'Nicaragua'})
# │       └── AnyNode(data={'id': 'Panama'})
# └── AnyNode(data={'id': ''})
#     └── AnyNode(data={'id': 'Northern America'})
#         ├── AnyNode(data={'id': 'Bermuda'})
#         ├── AnyNode(data={'id': 'Canada'})
#         ├── AnyNode(data={'id': 'Greenland'})
#         └── AnyNode(data={'id': 'United States'})

# %% [markdown]
# To give audience a direct impact, we add the median data (The level of income or expenditure per day below which half of the population live.) to each country. In order to achieve that, we need to match 2 datasets, while the matching point is the country name.

# %%
df_tree = pd.read_excel("out.xlsx")
for i in range(len(df_tree["country"])):
    for node in LevelOrderIter(root):
        if node.data["id"] == df_tree["country"][i]:
            node.median = df_tree["median"][i]

for node in LevelOrderIter(root):
    node.name = node.data["id"]
    del node.data
print(RenderTree(root))
# Out:
# AnyNode(median=6.92, name='World')
# ├── AnyNode(name='Asia')
# │   ├── AnyNode(name='Southern Asia')
# │   │   ├── AnyNode(name='Afghanistan')
# │   │   ├── AnyNode(median=3.110258264324849, name='Bangladesh')
# │   │   ├── AnyNode(median=6.702652894737087, name='Bhutan')
# │   │   ├── AnyNode(median=4.103054962429613, name='India')
# │   │   ├── AnyNode(median=10.22163073544963, name='Iran')
# │   │   ├── AnyNode(median=14.35191939823969, name='Maldives')
# │   │   ├── AnyNode(median=3.16524183029679, name='Nepal')
# │   │   ├── AnyNode(median=3.788850780905248, name='Pakistan')
# │   │   └── AnyNode(median=6.170867326898343, name='Sri Lanka')
# │   ├── AnyNode(name='Western Asia')
# │   │   ├── AnyNode(median=5.800004945187053, name='Armenia')
# │   │   ├── AnyNode(median=8.75371479287225, name='Azerbaijan')
# │   │   ├── AnyNode(name='Bahrain')
# │   │   ├── AnyNode(median=38.98015645283959, name='Cyprus')
# │   │   ├── AnyNode(median=5.836041408449774, name='Georgia')
# │   │   ├── AnyNode(median=5.345247895973078, name='Iraq')
# │   │   ├── AnyNode(median=32.35914934557186, name='Israel')
# │   │   ├── AnyNode(median=8.72710700337821, name='Jordan')
# │   │   ├── AnyNode(name='Kuwait')
# │   │   ├── AnyNode(median=21.13003182074932, name='Lebanon')
# │   │   ├── AnyNode(name='Oman')
# │   │   ├── AnyNode(name='Qatar')
# │   │   ├── AnyNode(name='Saudi Arabia')
# │   │   ├── AnyNode(median=8.97320889595096, name='Palestine')
# │   │   ├── AnyNode(name='Syrian')
# │   │   ├── AnyNode(median=14.29339859938751, name='Turkey')
# │   │   ├── AnyNode(median=68.60425516292128, name='United Arab Emirates')
# │   │   └── AnyNode(median=3.152859578680506, name='Yemen')
# │   ├── AnyNode(name='South-Eastern Asia')
# │   │   ├── AnyNode(name='Brunei Darussalam')
# │   │   ├── AnyNode(name='Cambodia')
# │   │   ├── AnyNode(median=5.787320925954285, name='Indonesia')
# │   │   ├── AnyNode(median=3.830960248391243, name='Laos')
# │   │   ├── AnyNode(median=20.30755775996729, name='Malaysia')
# │   │   ├── AnyNode(median=5.230861666506129, name='Myanmar')
# │   │   ├── AnyNode(median=5.805019954361698, name='Philippines')
# │   │   ├── AnyNode(name='Singapore')
# │   │   ├── AnyNode(median=12.52119758654609, name='Thailand')
# │   │   ├── AnyNode(median=2.658419434587597, name='Timor')
# │   │   └── AnyNode(median=8.749955335108229, name='Vietnam')
# │   ├── AnyNode(name='Eastern Asia')
# │   │   ├── AnyNode(median=13.0091490487635, name='China')
# │   │   ├── AnyNode(median=39.05675410467071, name='Japan')
# │   │   ├── AnyNode(median=7.734838585072671, name='Mongolia')
# │   │   └── AnyNode(median=37.33464578345079, name='South Korea')
# │   └── AnyNode(name='Central Asia')
# │       ├── AnyNode(median=10.57105061092753, name='Kazakhstan')
# │       ├── AnyNode(median=4.969394275424222, name='Kyrgyzstan')
# │       ├── AnyNode(median=5.464681209441886, name='Tajikistan')
# │       ├── AnyNode(median=1.901898285898674, name='Turkmenistan')
# │       └── AnyNode(median=1.621929608229898, name='Uzbekistan')
# ├── AnyNode(name='Europe')
# │   ├── AnyNode(name='Southern Europe')
# │   │   ├── AnyNode(median=10.83164622096564, name='Albania')
# │   │   ├── AnyNode(name='Andorra')
# │   │   ├── AnyNode(median=16.2341407198169, name='Bosnia and Herzegovina')
# │   │   ├── AnyNode(median=22.46613079108566, name='Croatia')
# │   │   ├── AnyNode(name='Gibraltar')
# │   │   ├── AnyNode(median=21.17635682659008, name='Greece')
# │   │   ├── AnyNode(median=36.2114652537926, name='Italy')
# │   │   ├── AnyNode(median=42.32308342815605, name='Malta')
# │   │   ├── AnyNode(median=12.66326755369148, name='Montenegro')
# │   │   ├── AnyNode(median=26.6095184790854, name='Portugal')
# │   │   ├── AnyNode(name='San Marino')
# │   │   ├── AnyNode(median=13.44119074410091, name='Serbia')
# │   │   ├── AnyNode(median=35.31029377680492, name='Slovenia')
# │   │   ├── AnyNode(median=34.21031817561074, name='Spain')
# │   │   └── AnyNode(name='Macedonia')
# │   ├── AnyNode(name='Western Europe')
# │   │   ├── AnyNode(median=50.96867144586987, name='Austria')
# │   │   ├── AnyNode(median=46.38475568700201, name='Belgium')
# │   │   ├── AnyNode(median=44.99028389191115, name='France')
# │   │   ├── AnyNode(median=48.70814182156142, name='Germany')
# │   │   ├── AnyNode(name='Liechtenstein')
# │   │   ├── AnyNode(median=63.58423828707659, name='Luxembourg')
# │   │   ├── AnyNode(name='Monaco')
# │   │   ├── AnyNode(median=48.70537299424464, name='Netherlands')
# │   │   └── AnyNode(median=57.91094687335458, name='Switzerland')
# │   ├── AnyNode(name='Eastern Europe')
# │   │   ├── AnyNode(median=19.14894472561082, name='Belarus')
# │   │   ├── AnyNode(median=18.66035339064578, name='Bulgaria')
# │   │   ├── AnyNode(median=30.04106997813182, name='Czechia')
# │   │   ├── AnyNode(median=24.15946709391712, name='Hungary')
# │   │   ├── AnyNode(median=15.93926382504037, name='Poland')
# │   │   ├── AnyNode(median=8.683898315169522, name='Moldova')
# │   │   ├── AnyNode(median=17.61316621759726, name='Romania')
# │   │   ├── AnyNode(median=15.17312153119123, name='Russia')
# │   │   ├── AnyNode(median=24.47826550365238, name='Slovakia')
# │   │   └── AnyNode(median=12.7279237224021, name='Ukraine')
# │   └── AnyNode(name='Northern Europe')
# │       ├── AnyNode(median=48.41527429372794, name='Denmark')
# │       ├── AnyNode(median=32.39102855314226, name='Estonia')
# │       ├── AnyNode(median=46.23118622112795, name='Finland')
# │       ├── AnyNode(median=53.27985865102415, name='Iceland')
# │       ├── AnyNode(median=44.24420610085726, name='Ireland')
# │       ├── AnyNode(median=24.6556554966971, name='Latvia')
# │       ├── AnyNode(median=27.15203781994917, name='Lithuania')
# │       ├── AnyNode(median=63.18894591340699, name='Norway')
# │       ├── AnyNode(median=49.98920694502409, name='Sweden')
# │       └── AnyNode(median=40.83672616873287, name='United Kingdom')
# ├── AnyNode(name='Africa')
# │   ├── AnyNode(name='Northern Africa')
# │   │   ├── AnyNode(median=7.15852568018615, name='Algeria')
# │   │   ├── AnyNode(median=4.06936029972045, name='Egypt')
# │   │   ├── AnyNode(name='Libya')
# │   │   ├── AnyNode(median=7.441964455491266, name='Morocco')
# │   │   ├── AnyNode(median=3.500351817873737, name='Sudan')
# │   │   └── AnyNode(median=9.223565786029882, name='Tunisia')
# │   ├── AnyNode(name='Middle Africa')
# │   │   ├── AnyNode(median=1.901954535963813, name='Angola')
# │   │   ├── AnyNode(median=3.41110795697717, name='Cameroon')
# │   │   ├── AnyNode(median=1.345688079004808, name='Central African Republic')
# │   │   ├── AnyNode(median=2.447748927478051, name='Chad')
# │   │   ├── AnyNode(median=2.366651334851676, name='Congo')
# │   │   ├── AnyNode(name='Democratic Republic of the Congo')
# │   │   ├── AnyNode(name='Equatorial Guinea')
# │   │   ├── AnyNode(median=7.614728226430608, name='Gabon')
# │   │   └── AnyNode(median=2.90589283625206, name='Sao Tome and Principe')
# │   ├── AnyNode(name='Western Africa')
# │   │   ├── AnyNode(median=3.143883146567879, name='Benin')
# │   │   ├── AnyNode(median=2.51075957506314, name='Burkina Faso')
# │   │   ├── AnyNode(median=6.451717901956318, name='Cape Verde')
# │   │   ├── AnyNode(median=4.122147487337441, name="Cote d'Ivoire")
# │   │   ├── AnyNode(median=3.789830892581235, name='Gambia')
# │   │   ├── AnyNode(median=4.976451640137421, name='Ghana')
# │   │   ├── AnyNode(median=2.798147910473777, name='Guinea')
# │   │   ├── AnyNode(median=2.793225736926841, name='Guinea-Bissau')
# │   │   ├── AnyNode(median=2.065502214222879, name='Liberia')
# │   │   ├── AnyNode(median=3.22960757929893, name='Mali')
# │   │   ├── AnyNode(median=4.823435049651368, name='Mauritania')
# │   │   ├── AnyNode(median=2.142134591198084, name='Niger')
# │   │   ├── AnyNode(median=2.260831728394824, name='Nigeria')
# │   │   ├── AnyNode(name='Saint Helena')
# │   │   ├── AnyNode(median=4.108132742261487, name='Senegal')
# │   │   ├── AnyNode(median=2.096139962384096, name='Sierra Leone')
# │   │   └── AnyNode(median=3.111200215689234, name='Togo')
# │   ├── AnyNode(name='Southern Africa')
# │   │   ├── AnyNode(median=4.373573173886359, name='Botswana')
# │   │   ├── AnyNode(median=3.21141803801032, name='Lesotho')
# │   │   ├── AnyNode(median=5.376503720840577, name='Namibia')
# │   │   ├── AnyNode(median=4.450887849138181, name='South Africa')
# │   │   └── AnyNode(name='Swaziland')
# │   └── AnyNode(name='Eastern Africa')
# │       ├── AnyNode(median=1.30305806373987, name='Burundi')
# │       ├── AnyNode(median=3.83900347967289, name='Comoros')
# │       ├── AnyNode(median=3.844242168350824, name='Djibouti')
# │       ├── AnyNode(name='Eritrea')
# │       ├── AnyNode(median=2.546263348498957, name='Ethiopia')
# │       ├── AnyNode(median=2.394905114724244, name='Kenya')
# │       ├── AnyNode(median=1.0480706758195, name='Madagascar')
# │       ├── AnyNode(median=1.266588266076092, name='Malawi')
# │       ├── AnyNode(median=10.50004444291589, name='Mauritius')
# │       ├── AnyNode(name='Mayotte')
# │       ├── AnyNode(median=1.451965955431691, name='Mozambique')
# │       ├── AnyNode(name='R茅union')
# │       ├── AnyNode(median=1.70385283833329, name='Rwanda')
# │       ├── AnyNode(median=17.8156401098791, name='Seychelles')
# │       ├── AnyNode(median=1.392387298094248, name='Somalia')
# │       ├── AnyNode(median=1.047836633655295, name='South Sudan')
# │       ├── AnyNode(median=2.230569423029636, name='Uganda')
# │       ├── AnyNode(median=1.923207054294284, name='Tanzania')
# │       ├── AnyNode(median=1.49450869983757, name='Zambia')
# │       └── AnyNode(median=2.358416837731384, name='Zimbabwe')
# ├── AnyNode(name='Oceania')
# │   ├── AnyNode(name='Polynesia')
# │   │   ├── AnyNode(median=6.953232817088473, name='Samoa')
# │   │   ├── AnyNode(name='Cook Islands')
# │   │   ├── AnyNode(name='French Polynesia')
# │   │   ├── AnyNode(name='Niue')
# │   │   ├── AnyNode(median=6.953232817088473, name='Samoa')
# │   │   ├── AnyNode(name='Tokelau')
# │   │   ├── AnyNode(median=7.622423118529698, name='Tonga')
# │   │   ├── AnyNode(median=5.752042068202308, name='Tuvalu')
# │   │   └── AnyNode(name='Wallis and Futuna Islands')
# │   ├── AnyNode(name='Australia and New Zealand')
# │   │   ├── AnyNode(median=47.48055878384665, name='Australia')
# │   │   └── AnyNode(name='New Zealand')
# │   ├── AnyNode(name='Melanesia')
# │   │   ├── AnyNode(median=5.536176500752969, name='Fiji')
# │   │   ├── AnyNode(name='New Caledonia')
# │   │   ├── AnyNode(median=2.402483566413286, name='Papua New Guinea')
# │   │   ├── AnyNode(median=2.847993535824852, name='Solomon Islands')
# │   │   └── AnyNode(median=4.286327495473021, name='Vanuatu')
# │   └── AnyNode(median=3.872120236916465, name='Micronesia')
# │       ├── AnyNode(name='Guam')
# │       ├── AnyNode(median=4.900522373374244, name='Kiribati')
# │       ├── AnyNode(median=8.451241229453817, name='Marshall Islands')
# │       ├── AnyNode(median=3.872120236916465, name='Micronesia')
# │       ├── AnyNode(median=6.134017303124919, name='Nauru')
# │       ├── AnyNode(name='Northern Mariana Islands')
# │       └── AnyNode(name='Palau')
# ├── AnyNode(name='Latin America')
# │   ├── AnyNode(name='Caribbean')
# │   │   ├── AnyNode(name='Anguilla')
# │   │   ├── AnyNode(name='Antigua and Barbuda')
# │   │   ├── AnyNode(name='Aruba')
# │   │   ├── AnyNode(name='Bahamas')
# │   │   ├── AnyNode(name='Barbados')
# │   │   ├── AnyNode(name='British Virgin Islands')
# │   │   ├── AnyNode(name='Bonaire, Sint Eustatius and Saba')
# │   │   ├── AnyNode(name='Cayman Islands')
# │   │   ├── AnyNode(name='Cuba')
# │   │   ├── AnyNode(name='Cura莽ao')
# │   │   ├── AnyNode(name='Dominica')
# │   │   ├── AnyNode(median=10.53942424011338, name='Dominican Republic')
# │   │   ├── AnyNode(name='Grenada')
# │   │   ├── AnyNode(name='Guadeloupe')
# │   │   ├── AnyNode(median=1.698289359342498, name='Haiti')
# │   │   ├── AnyNode(median=7.950248244829013, name='Jamaica')
# │   │   ├── AnyNode(name='Martinique')
# │   │   ├── AnyNode(name='Montserrat')
# │   │   ├── AnyNode(name='Puerto Rico')
# │   │   ├── AnyNode(name='Saint Kitts and Nevis')
# │   │   ├── AnyNode(median=12.3812111471325, name='Saint Lucia')
# │   │   ├── AnyNode(name='Saint Vincent and the Grenadines')
# │   │   ├── AnyNode(name='Sint Maarten (Dutch part)')
# │   │   ├── AnyNode(median=7.859004259083307, name='Trinidad and Tobago')
# │   │   ├── AnyNode(name='Turks and Caicos Islands')
# │   │   └── AnyNode(name='United States Virgin Islands')
# │   ├── AnyNode(name='South America')
# │   │   ├── AnyNode(median=12.17601799114082, name='Argentina')
# │   │   ├── AnyNode(median=9.773214914667834, name='Bolivia')
# │   │   ├── AnyNode(median=13.02353169268163, name='Brazil')
# │   │   ├── AnyNode(median=17.33801128727532, name='Chile')
# │   │   ├── AnyNode(median=7.165499676999464, name='Colombia')
# │   │   ├── AnyNode(median=8.091500819574463, name='Ecuador')
# │   │   ├── AnyNode(name='Falkland Islands (Malvinas)')
# │   │   ├── AnyNode(name='French Guiana')
# │   │   ├── AnyNode(median=5.401772701964792, name='Guyana')
# │   │   ├── AnyNode(median=11.21949791855335, name='Paraguay')
# │   │   ├── AnyNode(median=7.835965986192532, name='Peru')
# │   │   ├── AnyNode(median=5.603907364650947, name='Suriname')
# │   │   ├── AnyNode(median=18.8556367330828, name='Uruguay')
# │   │   └── AnyNode(median=7.791440155110353, name='Venezuela')
# │   └── AnyNode(name='Central America')
# │       ├── AnyNode(median=5.279236304737333, name='Belize')
# │       ├── AnyNode(median=12.60884769566, name='Costa Rica')
# │       ├── AnyNode(median=9.062244952902782, name='El Salvador')
# │       ├── AnyNode(median=5.58047629745663, name='Guatemala')
# │       ├── AnyNode(median=5.657554068323821, name='Honduras')
# │       ├── AnyNode(median=8.418795931889417, name='Mexico')
# │       ├── AnyNode(median=7.390502874120497, name='Nicaragua')
# │       └── AnyNode(median=17.47715568663098, name='Panama')
# └── AnyNode(name='')
#     └── AnyNode(name='Northern America')
#         ├── AnyNode(name='Bermuda')
#         ├── AnyNode(median=51.10365549318456, name='Canada')
#         ├── AnyNode(name='Greenland')
#         └── AnyNode(median=59.68785948476514, name='United States')

# %%
# then we export the data in a json file for us to use
# with open("tree.json", 'w') as file:
#     exporter.write(root, file)

# %% [markdown]
# ### Poverty rate
# This dataset concludes the poverty rate of each country.
#
# Data Source: OECD. https://data.oecd.org/inequality/poverty-rate.htm

# %%
df_poverty_rate = pd.read_csv("poverty_rate.csv")
df_poverty_rate
# Out:
#      LOCATION INDICATOR SUBJECT MEASURE FREQUENCY  TIME  Value Flag Codes
# 0         AUS   POVERTY    0_17      RT         A  2012  0.129        NaN
# 1         AUS   POVERTY    0_17      RT         A  2014  0.130        NaN
# 2         AUS   POVERTY    0_17      RT         A  2016  0.125        NaN
# 3         AUS   POVERTY    0_17      RT         A  2018  0.133        NaN
# 4         AUS   POVERTY    0_17      RT         A  2020  0.133        NaN
# ...       ...       ...     ...     ...       ...   ...    ...        ...
# 2059      ROU   POVERTY  66MORE      RT         A  2015  0.148        NaN
# 2060      ROU   POVERTY  66MORE      RT         A  2016  0.161        NaN
# 2061      ROU   POVERTY  66MORE      RT         A  2017  0.185        NaN
# 2062      ROU   POVERTY  66MORE      RT         A  2018  0.189        NaN
# 2063      ROU   POVERTY  66MORE      RT         A  2019  0.199        NaN
#
# [2064 rows x 8 columns]

# %% [markdown]
# It has been divided in 4 age categories: 0-17, 18-65, >65 and all.

# %%
df_poverty_rate["SUBJECT"].unique()
# Out:
# array(['0_17', 'TOT', '18_65', '66MORE'], dtype=object)

# %%
df_poverty_rate["Value"].describe()
# Out:
# count    2064.000000
# mean        0.125180
# std         0.064124
# min         0.018000
# 25%         0.082000
# 50%         0.115000
# 75%         0.156000
# max         0.478000
# Name: Value, dtype: float64

# %% [markdown]
# ### Further data engineering
# #### Imputation of missing values
# As we talked before, there are many blank cells in the dataset. One way of dealing it is to delete the column. However, due to the frequent miss of data from poverty-striken countries, it is almost impossible to continue working if we delete the column every time. So I choose imputation.
#
# One naive way is to use univariate imputation. However it does not seem to fit the data processing of this massive dataset. Thus, I shall use multivariate imputation and I think KNN method is suitable in this case.
#
# KNN method fills in missing values using the k-Nearest Neighbors approach. By default, a euclidean distance metric that supports missing values is used to find the nearest neighbors. Each missing feature is imputed using values from nearest neighbors that have a value for the feature. The feature of the neighbors are averaged uniformly or weighted by distance to each neighbor.

# %%
import numpy as np
from sklearn.impute import KNNImputer

X = df.drop(
    ["country", "year", "reporting_level", "welfare_type", "ppp_version", "survey_year", "survey_comparability"],
    axis=1)
imp = KNNImputer(n_neighbors=2, weights="uniform")
imputed_X = np.round_(imp.fit_transform(X), decimals=3)
print(imputed_X)
# Out:
# [[ 0.921 11.174 44.618 ...  3.569  1.889  1.889]
#  [ 1.571 14.132 49.67  ...  3.979  2.09   1.904]
#  [ 0.861  8.716 38.545 ...  3.873  1.978  1.958]
#  ...
#  [21.58  47.857 77.945 ...  6.713  2.774  2.42 ]
#  [34.206 61.584 84.109 ...  6.575  3.07   2.142]
#  [39.755 64.51  85.016 ...  8.191  3.4    2.409]]

# %% [markdown]
# Now we have a workable matrix which is also suitable for further dimention reduction.
